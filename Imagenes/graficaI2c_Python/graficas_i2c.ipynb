# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
rise_time = 1000e-9
print(rise_time)
# Out:
# 1e-06

# %%
cb = np.arange(50e-12,410e-12,10e-12)

# %%
print(cb)
# Out:
# [3.0e-11 4.0e-11 5.0e-11 6.0e-11 7.0e-11 8.0e-11 9.0e-11 1.0e-10 1.1e-10
#  1.2e-10 1.3e-10 1.4e-10 1.5e-10 1.6e-10 1.7e-10 1.8e-10 1.9e-10 2.0e-10
#  2.1e-10 2.2e-10 2.3e-10 2.4e-10 2.5e-10 2.6e-10 2.7e-10 2.8e-10 2.9e-10
#  3.0e-10 3.1e-10 3.2e-10 3.3e-10 3.4e-10 3.5e-10 3.6e-10 3.7e-10 3.8e-10
#  3.9e-10 4.0e-10 4.1e-10 4.2e-10]

# %%
rp = rise_time/(0.8473*cb)

# %%
plt.plot(cb,rp)
plt.xlabel("Capacitancia bus F")
plt.ylabel("Máxima resistencia $\Omega$")
plt.grid(True)
plt.legend(['Modo estándar'])
plt.show()

# %%
vcc = np.arange(2,5,0.5)

# %%
vcc_l_2=np.arange(0.4,2,0.5)

# %%
vol = 0.4

# %%
iol=0.003

# %%
rp_less_2=(vcc-vol)/0.002

# %%
rp_greate_2=(vcc-vol)/0.003

# %%
plt.plot(vcc,rp_less_2)
plt.xlabel("Voltaje alimentación V")
plt.ylabel("Mínima resistencia $\Omega$")
plt.grid(True)
plt.legend(['Vcc > 2'])
plt.show()

# %%
noise = (np.random.normal(0,1,1000))
noise_sorted = sorted(np.random.normal(0,1,1000))

# %%
import scipy.stats as stats
import pylab as pl

# %%
fit = stats.norm.pdf(noise_sorted, np.mean(noise_sorted), np.std(noise_sorted))

# %%
pl.plot(noise_sorted,fit)

# %%
plt.plot(noise)
plt.xlabel("tiempo t")
plt.ylabel("")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-8bba79aa0c67> in <module>
# ----> 1 plt.plot(noise)
#       2 plt.xlabel("tiempo t")
#       3 plt.ylabel("")
#       4 plt.grid(True)
#       5 plt.show()
#
# NameError: name 'noise' is not defined

# %%
str(np.mean(noise))
# Out:
# '0.0043969882384804464'

# %%
q = 0.3333
domain = np.linspace(0, 10, 1000)
x = 2.5*np.sin(domain)

y = q*np.round(x/q)

plt.plot(domain,y+2.5)
plt.plot(domain,x+2.5)
plt.legend(['cuantizada','entrada'])
plt.xlabel("tiempo t")
plt.ylabel("Voltaje V")
plt.grid(True)
plt.show()
